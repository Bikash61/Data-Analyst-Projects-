# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
df.shape
# Out:
# (103, 7)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df['Production (Tons)'] = df['Production (Tons)'].str.replace(".",'')
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace('.','').str.replace(',','.')
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].str.replace('.','')
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205               751675
# 1                     260721           4950000               703935
# 2                      88287           1675215               734591
# 3                   1264.303           1336575               654422
# 4                     324219           1130820                57879

# %%
df.rename(columns = {'Production (Tons)': 'Production_(Tons)'}, inplace = True)
df.rename(columns = {'Production per Person (Kg)': 'Production_per_Person(Kg)'}, inplace = True )
df.rename(columns = {'Acreage (Hectare)': 'Acreage(Hectare)'}, inplace = True)
df.rename(columns = {'Yield (Kg / Hectare)': 'Yield(Kg/Hectare)'}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production_(Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205            751675
# 1                    260721          4950000            703935
# 2                     88287          1675215            734591
# 3                  1264.303          1336575            654422
# 4                    324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production_(Tons)            0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df = df.dropna().reset_index()

# %%
df.shape
# Out:
# (102, 8)

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production_(Tons)  \
# 0      0           0    Brazil  South America         768678382
# 1      1           1     India           Asia         348448000
# 2      2           2     China           Asia         123059739
# 3      3           3  Thailand           Asia          87468496
# 4      4           4  Pakistan           Asia          65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205            751675
# 1                    260721          4950000            703935
# 2                     88287          1675215            734591
# 3                  1264.303          1336575            654422
# 4                    324219          1130820             57879

# %%
df.drop(['Unnamed: 0','index'],axis = 1, inplace = True)

# %%
df.head()
# Out:
#     Country      Continent Production_(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America         768678382                  3668.531
# 1     India           Asia         348448000                    260721
# 2     China           Asia         123059739                     88287
# 3  Thailand           Asia          87468496                  1264.303
# 4  Pakistan           Asia          65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205            751675
# 1          4950000            703935
# 2          1675215            734591
# 3          1336575            654422
# 4          1130820             57879

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production_(Tons)            object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df['Production_(Tons)'] = df['Production_(Tons)'].astype('float')
df['Production_per_Person(Kg)'] = df['Production_per_Person(Kg)'].astype('float')
df['Acreage(Hectare)'] = df['Acreage(Hectare)'].astype('float')
df['Yield(Kg/Hectare)'] = df['Yield(Kg/Hectare)'].astype('float')

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production_(Tons)            float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production_(Tons)            102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production_(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382.0                   3668.531
# 1     India           Asia        348448000.0                 260721.000
# 2     China           Asia        123059739.0                  88287.000
# 3  Thailand           Asia         87468496.0                   1264.303
# 4  Pakistan           Asia         65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0           751675.0
# 1         4950000.0           703935.0
# 2         1675215.0           734591.0
# 3         1336575.0           654422.0
# 4         1130820.0            57879.0

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
## Bar Graph
df['Continent'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.distplot(df['Production_(Tons)'])
plt.subplot(2,2,2)
sns.distplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.distplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.distplot(df['Yield(Kg/Hectare)'])
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10556\2366356030.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production_(Tons)'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10556\2366356030.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production_(Tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield(Kg/Hectare)'])
plt.show()

# %%
df.describe()
# Out:
#        Production_(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count       1.020000e+02                 102.000000      1.020000e+02
# mean        1.850372e+07              112952.435755      2.498981e+05
# std         8.419149e+07              176651.341929      1.137003e+06
# min         1.000000e+00                   0.000000      0.000000e+00
# 25%         6.251875e+04                3671.910000      1.104000e+03
# 50%         1.440044e+06               25572.500000      1.655800e+04
# 75%         6.426824e+06              146384.750000      8.047400e+04
# max         7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count       1.020000e+02
# mean        5.018502e+05
# std         3.169530e+05
# min         1.000000e+01
# 25%         2.487505e+05
# 50%         5.102500e+05
# 75%         7.198920e+05
# max         1.290493e+06

# %% [markdown]
# ## Bivariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production_(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382.0                   3668.531
# 1     India           Asia        348448000.0                 260721.000
# 2     China           Asia        123059739.0                  88287.000
# 3  Thailand           Asia         87468496.0                   1264.303
# 4  Pakistan           Asia         65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0           751675.0
# 1         4950000.0           703935.0
# 2         1675215.0           734591.0
# 3         1336575.0           654422.0
# 4         1130820.0            57879.0

# %%
df_new = df[['Country', 'Production_(Tons)']].set_index('Country')

# %%
df_new
# Out:
#            Production_(Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Spain                  394.0
# Lebanon                 97.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [102 rows x 1 columns]

# %%
df_new['Production(Tons)_Percent'] = df_new['Production_(Tons)']*100/df_new['Production_(Tons)'].sum()

# %%
df_new.head()
# Out:
#           Production_(Tons)  Production(Tons)_Percent
# Country
# Brazil          768678382.0                 40.727285
# India           348448000.0                 18.462001
# China           123059739.0                  6.520138
# Thailand         87468496.0                  4.634389
# Pakistan         65450704.0                  3.467809

# %%
df_new['Production_(Tons)'].head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Country'>

# %%
df_new['Production_(Tons)'].head(10).plot(kind = 'pie')
# Out:
# <Axes: ylabel='Production_(Tons)'>

# %%
ax = sns.barplot(data = df_new.head(10), x = 'Country', y = 'Production_(Tons)')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7940\783993961.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Find the country having highest Land

# %%
df_acr = df.sort_values('Acreage(Hectare)',ascending = False)
ax = sns.barplot(data = df_acr.head(10), x = 'Country',y = 'Acreage(Hectare)')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7940\3469740926.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Which country has the highest yield per hectare

# %%
df_acr = df.sort_values('Yield(Kg/Hectare)',ascending = False)
ax = sns.barplot(data = df_acr.head(10), x = 'Country',y = 'Yield(Kg/Hectare)')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7940\568893536.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Which country has the highest production per person kg

# %%
df_acr = df.sort_values('Production_per_Person(Kg)',ascending = False)
ax = sns.barplot(data = df_acr.head(10), x = 'Country',y = 'Production_per_Person(Kg)')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7940\2895207103.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Correlation

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

# %%
numeric_df.corr()
# Out:
#                            Production_(Tons)  Production_per_Person(Kg)  \
# Production_(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)           0.015000                   1.000000
# Acreage(Hectare)                    0.997550                   0.012557
# Yield(Kg/Hectare)                   0.121125                  -0.043603
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production_(Tons)                  0.997550           0.121125
# Production_per_Person(Kg)          0.012557          -0.043603
# Acreage(Hectare)                   1.000000           0.107826
# Yield(Kg/Hectare)                  0.107826           1.000000

# %%
sns.heatmap(numeric_df.corr(),annot = True, cmap = 'Greens')
# Out:
# <Axes: >

# %% [markdown]
# ## Do countries with highest land produce more sugarcane

# %%
sns.scatterplot(data = df, x= 'Acreage(Hectare)',y = 'Production_(Tons)')
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production_(Tons)'>

# %% [markdown]
# ## Do countries with more sugarcane per hectare produces more sugarcane in total?

# %%
sns.scatterplot(data = df, x ='Yield(Kg/Hectare)',y = 'Production_(Tons)' )
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production_(Tons)'>

# %% [markdown]
# ## Analysis for continent

# %%
df_continent = df.groupby('Continent').sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production_(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa                89681472.0                2332636.293         1439089.0
# Asia                 721930425.0                1857769.303        10608319.0
# Europe                    5823.0                    536.000              71.0
# North America        173995947.0                3796081.508         1581983.0
# Oceania               36177574.0                  28593.605          490909.0
# ...

# %% [markdown]
# ## Which continent produces maximum sugarcane

# %%
df_continent['Production_(Tons)'].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## How much land each continent have

# %%
df_continent['Acreage(Hectare)'].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## Do number of countries in a Continent effects production of Sugarcane

# %%
df_continent['Number_of_countires'] = df.groupby('Continent').count()['Country']

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production_(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa                89681472.0                2332636.293         1439089.0
# Asia                 721930425.0                1857769.303        10608319.0
# Europe                    5823.0                    536.000              71.0
# North America        173995947.0                3796081.508         1581983.0
# Oceania               36177574.0                  28593.605          490909.0
# ...

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent, x='Number_of_countires',y='Production_(Tons)')
plt.xticks(df_continent['Number_of_countires'],continent_names,rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x20c08c0e510>,
# ...
#  [Text(38, 0, 'Africa'),
#   Text(25, 0, 'Asia'),
#   Text(2, 0, 'Europe'),
#   Text(22, 0, 'North America'),
#   Text(4, 0, 'Oceania'),
#   Text(11, 0, 'South America')])

# %%
numeric_df = df_continent.select_dtypes(include=[np.number])
numeric_df.corr()
# Out:
#                            Production_(Tons)  Production_per_Person(Kg)  \
# Production_(Tons)                   1.000000                   0.522211
# Production_per_Person(Kg)           0.522211                   1.000000
# Acreage(Hectare)                    0.994897                   0.463215
# Yield(Kg/Hectare)                   0.104312                   0.523627
# Number_of_countires                 0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production_(Tons)                  0.994897           0.104312
# Production_per_Person(Kg)          0.463215           0.523627
# Acreage(Hectare)                   1.000000           0.126764
# Yield(Kg/Hectare)                  0.126764           1.000000
# Number_of_countires                0.132817           0.983807
#
#                            Number_of_countires
# Production_(Tons)                     0.109244
# Production_per_Person(Kg)             0.540086
# ...

# %%
sns.heatmap(data = numeric_df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Production Distribution by continent

# %%
df_continent['Production_(Tons)'].plot(kind = 'pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='Production_(Tons)'>
